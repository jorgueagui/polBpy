# %%
# %matplotlib inline

# %% [markdown]
# # DISPERSION ANALYSIS II
# Author: Jordan Guerra (for Villanova University). May 2024.
#
# This tutorial illustrates the more advanced use of the package *polBpy* for performing angular dispersion analysis and studying the magnetoturbulent state of gas using dust polarimetric observations. Parameters determined with this anaylsis can be used for DCF calculations.
#
# This tutorial uses data from literature listed [here.](https://github.com/jorgueagui/polBpy/blob/9039d4af5d25c49130bf51be7fe0ce363424edcc/refs.md)
#
# **EXAMPLE I**: This example shows how to perform local dispersion analysis for a region of dust/gas. This analysis follows these steps: 1) calculating the autocorrelation function of the polarized flux, and measuring its width as estimation of the cloud's depth; 2) calculating a pixel-by-pixel *dispersion function* by defining a circular kernel of radius $w$ centered at each pixel; 3) fitting the *dispersion functions* with the two-scale model of Houde+09 using a Markov-Chain Montecarlo (MCMC) approach and determining the magnetotubrulent parameters. We reproduce here some results from Guerra+21, which presents uses SOFIA/HAWC+ multiwavelength polarimetric observations of the OMC-1 region.

# %%
from polBpy import dispersion, fitting, utils
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In this example we try to reproduce resukts from Guerra+21. Specifically, reproducing the plots in Figure 3, which utilizes the 214 $\mu$m data. First, we load all the necessary data

# %%
from astropy.io import fits
import os
cdir = os.path.dirname(os.getcwd())
file = cdir+"/data/PolBpy_Tutorial_IV_data.fits"
data = fits.open(file)
print(data.info())
# Out:
# Filename: /Users/jguerraa/Desktop/polBpy/data/PolBpy_Tutorial_IV_data.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  STOKES I      1 PrimaryHDU     597   (102, 114)   float64
#   1  ERROR I       1 ImageHDU        27   (102, 114)   float64
#   2  STOKES Q      1 ImageHDU        18   (102, 114)   float64
#   3  ERROR Q       1 ImageHDU        18   (102, 114)   float64
#   4  STOKES U      1 ImageHDU        18   (102, 114)   float64
#   5  ERROR U       1 ImageHDU        18   (102, 114)   float64
#   6  IMAGE MASK    1 ImageHDU        27   (102, 114)   float64
#   7  PERCENT POL    1 ImageHDU        18   (102, 114)   float64
#   8  DEBIASED PERCENT POL    1 ImageHDU        18   (102, 114)   float64
#   9  ERROR PERCENT POL    1 ImageHDU        18   (102, 114)   float64
#  10  POL ANGLE     1 ImageHDU        18   (102, 114)   float64
#  11  ROTATED POL ANGLE    1 ImageHDU        18   (102, 114)   float64
#  12  ERROR POL ANGLE    1 ImageHDU        18   (102, 114)   float64
#  13  POL FLUX      1 ImageHDU        18   (102, 114)   float64
#  14  ERROR POL FLUX    1 ImageHDU        18   (102, 114)   float64
#  15  DEBIASED POL FLUX    1 ImageHDU        18   (102, 114)   float64
#  16  MERGED DATA    1 BinTableHDU    226   8R x 65C   [1J, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1J, 1J, 1E, 1K, 1K, 1J, 1E, 1E, 1J, 1E, 1E, 1E, 1E, 1E, 1E, 1B, 1E, 1E, 1E, 1E, 1E, 1E, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1J, 1D, 1J, 1D, 1D, 1D, 1J, 1J, 1J, 2624E, 2624E, 1E, 1J, 2624E, 2624E, D, D, D, 92A]
#  17  POL DATA      1 BinTableHDU     34   11628R x 10C   [J, J, D, D, D, D, D, D, D, D]
#  18  FINAL POL DATA    1 BinTableHDU     30   1711R x 8C   [D, D, D, D, D, D, D, D]
# None

# %% [markdown]
# and exclude all pixels with $p/p_{err}$ > 3.0 as done in Tutorial III

# %%
p_flux = data['DEBIASED POL FLUX'].data # 
p_flux_err = data['ERROR POL FLUX'].data #
pixel_size = data[0].header['CDELT2']*3600 #in arcsec
# Find the points
m = np.where(p_flux/p_flux_err > 3.0)
# Create the mask
mask = np.full_like(p_flux,0.0)
mask[m] = 1.0

# %% [markdown]
# Step 1: calculating $\Delta^{\prime}$ through the autocorrelation function. We call the autocorrelation function (for further details on this function see Tutorial III),

# %%
Delta_p, Delta_p_err = dispersion.autocorrelation(p_flux,p_flux_err,pixsize=pixel_size,mask=mask,plots=False,hwhm=True)

# %% [markdown]
# And print the $\Delta^{\prime}$ in the (multiple of) units of pixel_size (arcsec in this case)

# %%
print("Delta' = %2.2f +/- %2.2f [arcmin]"%(Delta_p,Delta_p_err))
# Out:
# Delta' = 1.55 +/- 0.12 [arcmin]

# %% [markdown]
# Step 2: calcualting the *dispersion function map*. In order to calculate the map of *dispersion functions*, we need to define the relevant variables, including the beam size, and the size of the circular kernel in pixel. Following Guerra+21 we define $w$=9 pixels

# %%
angles = data['ROTATED POL ANGLE'].data # 
angles_err = data['ERROR POL ANGLE'].data # 
beam_s = 4*pixel_size # FWHM value of the beam
win_s = 9 # pixel

# %% [markdown]
# Similarly to *dispersion_function*, *dispersion_function_map* takes the polarization angles, their errors, pixel size, beam, mask, and the kernel size. In addition, you can use the keyword *verb* to printout progress of the calculation. However, the larger the size of the area to process, printing out progress can significantly slow down the process. *verb=False* only prints out which pixels are not processed.

# %%
res1 = dispersion.dispersion_function_map(angles,angles_err,pixel_size,mask=mask,beam=beam_s,w=win_s,verb=False)
# Out:
# Analysis window size =  19 x 19
# Skipping Pixel = 9 9
# Skipping Pixel = 9 10
# Skipping Pixel = 9 11
# Skipping Pixel = 9 12
# Skipping Pixel = 9 13
# Skipping Pixel = 9 14
# Skipping Pixel = 9 15
# Skipping Pixel = 9 16
# Skipping Pixel = 9 17
# Skipping Pixel = 9 18
# Skipping Pixel = 9 19
# Skipping Pixel = 9 20
# Skipping Pixel = 9 21
# Skipping Pixel = 9 22
# Skipping Pixel = 9 23
# Skipping Pixel = 9 24
# Skipping Pixel = 9 25
# Skipping Pixel = 9 26
# Skipping Pixel = 9 27
# Skipping Pixel = 9 28
# Skipping Pixel = 9 29
# Skipping Pixel = 9 30
# Skipping Pixel = 9 31
# Skipping Pixel = 9 32
# Skipping Pixel = 9 33
# Skipping Pixel = 9 34
# Skipping Pixel = 9 35
# Skipping Pixel = 9 43
# Skipping Pixel = 9 44
# Skipping Pixel = 9 45
# /Users/jguerraa/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/jguerraa/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:222: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Users/jguerraa/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/jguerraa/Desktop/polBpy/polBpy/utils.py:95: RuntimeWarning: Mean of empty slice
#   rms = np.sqrt(np.nanmean(vec**2))
# /Users/jguerraa/Desktop/polBpy/polBpy/dispersion.py:153: RuntimeWarning: invalid value encountered in sqrt
#   errors_c[i]= np.sqrt( (sinDphisum[i]**2)*sigma2sum[i] + (sinDphisum[i]**2)*Dphisum[i] + \
# /Users/jguerraa/Desktop/polBpy/polBpy/utils.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   rms = (2.*np.std(vec)**4)/(len(vec)-1)
# Skipping Pixel = 9 56
# Skipping Pixel = 9 57
# Skipping Pixel = 9 89
# Skipping Pixel = 9 90
# Skipping Pixel = 9 91
# Skipping Pixel = 9 92
# Skipping Pixel = 10 9
# Skipping Pixel = 10 10
# Skipping Pixel = 10 11
# Skipping Pixel = 10 12
# Skipping Pixel = 10 13
# Skipping Pixel = 10 14
# Skipping Pixel = 10 15
# Skipping Pixel = 10 16
# Skipping Pixel = 10 17
# Skipping Pixel = 10 18
# Skipping Pixel = 10 19
# Skipping Pixel = 10 20
# Skipping Pixel = 10 21
# Skipping Pixel = 10 22
# Skipping Pixel = 10 23
# Skipping Pixel = 10 24
# Skipping Pixel = 10 25
# Skipping Pixel = 10 31
# Skipping Pixel = 10 32
# Skipping Pixel = 10 33
# Skipping Pixel = 10 34
# Skipping Pixel = 10 35
# Skipping Pixel = 10 44
# Skipping Pixel = 10 45
# Skipping Pixel = 10 56
# Skipping Pixel = 10 57
# Skipping Pixel = 10 78
# Skipping Pixel = 10 89
# Skipping Pixel = 10 90
# Skipping Pixel = 10 91
# Skipping Pixel = 10 92
# Skipping Pixel = 11 9
# Skipping Pixel = 11 10
# Skipping Pixel = 11 11
# Skipping Pixel = 11 12
# Skipping Pixel = 11 13
# Skipping Pixel = 11 14
# Skipping Pixel = 11 15
# Skipping Pixel = 11 16
# Skipping Pixel = 11 17
# Skipping Pixel = 11 18
# Skipping Pixel = 11 19
# Skipping Pixel = 11 20
# Skipping Pixel = 11 21
# Skipping Pixel = 11 22
# Skipping Pixel = 11 31
# Skipping Pixel = 11 32
# Skipping Pixel = 11 33
# Skipping Pixel = 11 34
# Skipping Pixel = 11 44
# Skipping Pixel = 11 45
# Skipping Pixel = 11 56
# Skipping Pixel = 11 68
# Skipping Pixel = 11 79
# Skipping Pixel = 11 80
# Skipping Pixel = 11 81
# Skipping Pixel = 11 82
# Skipping Pixel = 11 89
# Skipping Pixel = 11 90
# Skipping Pixel = 11 91
# Skipping Pixel = 11 92
# Skipping Pixel = 12 9
# Skipping Pixel = 12 10
# Skipping Pixel = 12 11
# Skipping Pixel = 12 12
# Skipping Pixel = 12 13
# Skipping Pixel = 12 14
# Skipping Pixel = 12 15
# Skipping Pixel = 12 16
# Skipping Pixel = 12 17
# Skipping Pixel = 12 18
# Skipping Pixel = 12 19
# Skipping Pixel = 12 20
# Skipping Pixel = 12 21
# Skipping Pixel = 12 22
# Skipping Pixel = 12 30
# Skipping Pixel = 12 33
# Skipping Pixel = 12 79
# Skipping Pixel = 12 80
# Skipping Pixel = 12 81
# Skipping Pixel = 12 82
# Skipping Pixel = 12 83
# Skipping Pixel = 12 86
# Skipping Pixel = 12 88
# Skipping Pixel = 12 89
# Skipping Pixel = 12 90
# Skipping Pixel = 12 91
# Skipping Pixel = 12 92
# Skipping Pixel = 13 9
# Skipping Pixel = 13 10
# Skipping Pixel = 13 11
# Skipping Pixel = 13 12
# Skipping Pixel = 13 13
# Skipping Pixel = 13 14
# Skipping Pixel = 13 15
# Skipping Pixel = 13 16
# Skipping Pixel = 13 17
# Skipping Pixel = 13 18
# Skipping Pixel = 13 19
# Skipping Pixel = 13 20
# Skipping Pixel = 13 21
# Skipping Pixel = 13 22
# Skipping Pixel = 13 67
# Skipping Pixel = 13 68
# Skipping Pixel = 13 72
# Skipping Pixel = 13 78
# Skipping Pixel = 13 79
# Skipping Pixel = 13 80
# Skipping Pixel = 13 81
# Skipping Pixel = 13 82
# Skipping Pixel = 13 83
# Skipping Pixel = 13 84
# Skipping Pixel = 13 85
# Skipping Pixel = 13 89
# Skipping Pixel = 13 90
# Skipping Pixel = 13 91
# Skipping Pixel = 13 92
# Skipping Pixel = 14 9
# Skipping Pixel = 14 10
# Skipping Pixel = 14 11
# Skipping Pixel = 14 12
# Skipping Pixel = 14 13
# Skipping Pixel = 14 14
# Skipping Pixel = 14 15
# Skipping Pixel = 14 16
# Skipping Pixel = 14 17
# Skipping Pixel = 14 18
# Skipping Pixel = 14 19
# Skipping Pixel = 14 20
# Skipping Pixel = 14 21
# Skipping Pixel = 14 22
# Skipping Pixel = 14 67
# Skipping Pixel = 14 68
# Skipping Pixel = 14 69
# Skipping Pixel = 14 71
# Skipping Pixel = 14 72
# Skipping Pixel = 14 73
# Skipping Pixel = 14 78
# Skipping Pixel = 14 79
# Skipping Pixel = 14 80
# Skipping Pixel = 14 81
# Skipping Pixel = 14 82
# Skipping Pixel = 14 83
# Skipping Pixel = 14 84
# Skipping Pixel = 14 90
# Skipping Pixel = 14 91
# Skipping Pixel = 14 92
# Skipping Pixel = 15 9
# Skipping Pixel = 15 10
# Skipping Pixel = 15 11
# Skipping Pixel = 15 12
# Skipping Pixel = 15 13
# Skipping Pixel = 15 14
# Skipping Pixel = 15 15
# Skipping Pixel = 15 16
# Skipping Pixel = 15 17
# Skipping Pixel = 15 18
# Skipping Pixel = 15 19
# Skipping Pixel = 15 20
# Skipping Pixel = 15 21
# Skipping Pixel = 15 22
# Skipping Pixel = 15 23
# Skipping Pixel = 15 68
# Skipping Pixel = 15 77
# Skipping Pixel = 15 78
# Skipping Pixel = 15 79
# Skipping Pixel = 15 80
# Skipping Pixel = 15 85
# Skipping Pixel = 15 89
# Skipping Pixel = 15 90
# Skipping Pixel = 15 91
# Skipping Pixel = 15 92
# Skipping Pixel = 16 9
# Skipping Pixel = 16 10
# Skipping Pixel = 16 11
# Skipping Pixel = 16 12
# Skipping Pixel = 16 13
# Skipping Pixel = 16 14
# Skipping Pixel = 16 15
# Skipping Pixel = 16 16
# Skipping Pixel = 16 17
# Skipping Pixel = 16 18
# Skipping Pixel = 16 19
# Skipping Pixel = 16 20
# Skipping Pixel = 16 21
# Skipping Pixel = 16 22
# Skipping Pixel = 16 23
# Skipping Pixel = 16 26
# Skipping Pixel = 16 77
# Skipping Pixel = 16 78
# Skipping Pixel = 16 79
# Skipping Pixel = 16 88
# Skipping Pixel = 16 89
# Skipping Pixel = 16 90
# Skipping Pixel = 16 91
# Skipping Pixel = 16 92
# Skipping Pixel = 17 9
# Skipping Pixel = 17 10
# Skipping Pixel = 17 11
# Skipping Pixel = 17 12
# Skipping Pixel = 17 13
# Skipping Pixel = 17 14
# Skipping Pixel = 17 15
# Skipping Pixel = 17 16
# Skipping Pixel = 17 17
# Skipping Pixel = 17 18
# Skipping Pixel = 17 19
# Skipping Pixel = 17 20
# Skipping Pixel = 17 21
# Skipping Pixel = 17 22
# Skipping Pixel = 17 23
# Skipping Pixel = 17 24
# Skipping Pixel = 17 27
# Skipping Pixel = 17 35
# Skipping Pixel = 17 78
# Skipping Pixel = 17 90
# Skipping Pixel = 17 91
# Skipping Pixel = 17 92
# Skipping Pixel = 18 9
# Skipping Pixel = 18 10
# Skipping Pixel = 18 11
# Skipping Pixel = 18 12
# Skipping Pixel = 18 13
# Skipping Pixel = 18 14
# Skipping Pixel = 18 15
# Skipping Pixel = 18 16
# Skipping Pixel = 18 17
# Skipping Pixel = 18 18
# Skipping Pixel = 18 19
# Skipping Pixel = 18 22
# Skipping Pixel = 18 23
# Skipping Pixel = 18 24
# Skipping Pixel = 18 90
# Skipping Pixel = 18 91
# Skipping Pixel = 18 92
# Skipping Pixel = 19 9
# Skipping Pixel = 19 10
# Skipping Pixel = 19 11
# Skipping Pixel = 19 12
# Skipping Pixel = 19 13
# Skipping Pixel = 19 14
# Skipping Pixel = 19 23
# Skipping Pixel = 19 24
# Skipping Pixel = 19 90
# Skipping Pixel = 19 91
# Skipping Pixel = 19 92
# Skipping Pixel = 20 9
# Skipping Pixel = 20 10
# Skipping Pixel = 20 11
# Skipping Pixel = 20 12
# Skipping Pixel = 20 13
# Skipping Pixel = 20 14
# Skipping Pixel = 20 23
# Skipping Pixel = 20 78
# Skipping Pixel = 20 90
# Skipping Pixel = 20 91
# Skipping Pixel = 20 92
# Skipping Pixel = 21 10
# Skipping Pixel = 21 11
# Skipping Pixel = 21 12
# Skipping Pixel = 21 13
# Skipping Pixel = 21 14
# Skipping Pixel = 21 23
# Skipping Pixel = 21 78
# Skipping Pixel = 21 90
# Skipping Pixel = 21 91
# Skipping Pixel = 21 92
# Skipping Pixel = 22 12
# Skipping Pixel = 22 13
# Skipping Pixel = 22 14
# Skipping Pixel = 22 91
# Skipping Pixel = 22 92
# Skipping Pixel = 23 13
# Skipping Pixel = 23 14
# Skipping Pixel = 23 79
# Skipping Pixel = 23 90
# Skipping Pixel = 23 91
# Skipping Pixel = 23 92
# Skipping Pixel = 24 13
# Skipping Pixel = 24 14
# Skipping Pixel = 24 79
# Skipping Pixel = 24 80
# Skipping Pixel = 24 90
# Skipping Pixel = 24 91
# Skipping Pixel = 24 92
# Skipping Pixel = 25 13
# Skipping Pixel = 25 14
# Skipping Pixel = 25 15
# Skipping Pixel = 25 78
# Skipping Pixel = 25 79
# Skipping Pixel = 25 80
# Skipping Pixel = 25 89
# Skipping Pixel = 25 90
# Skipping Pixel = 25 91
# Skipping Pixel = 25 92
# Skipping Pixel = 26 13
# Skipping Pixel = 26 14
# Skipping Pixel = 26 15
# Skipping Pixel = 26 78
# Skipping Pixel = 26 79
# Skipping Pixel = 26 80
# Skipping Pixel = 26 90
# Skipping Pixel = 26 91
# Skipping Pixel = 26 92
# Skipping Pixel = 27 13
# Skipping Pixel = 27 14
# Skipping Pixel = 27 15
# Skipping Pixel = 27 79
# Skipping Pixel = 27 80
# Skipping Pixel = 27 81
# Skipping Pixel = 27 82
# Skipping Pixel = 27 83
# Skipping Pixel = 27 84
# Skipping Pixel = 27 89
# Skipping Pixel = 27 90
# Skipping Pixel = 27 91
# Skipping Pixel = 27 92
# Skipping Pixel = 28 10
# Skipping Pixel = 28 13
# Skipping Pixel = 28 80
# Skipping Pixel = 28 81
# Skipping Pixel = 28 85
# Skipping Pixel = 28 86
# Skipping Pixel = 28 87
# Skipping Pixel = 28 88
# Skipping Pixel = 28 89
# Skipping Pixel = 28 90
# Skipping Pixel = 28 91
# Skipping Pixel = 28 92
# Skipping Pixel = 29 9
# Skipping Pixel = 29 10
# Skipping Pixel = 29 21
# Skipping Pixel = 29 90
# Skipping Pixel = 29 91
# Skipping Pixel = 29 92
# Skipping Pixel = 30 9
# Skipping Pixel = 30 10
# Skipping Pixel = 30 20
# Skipping Pixel = 30 90
# Skipping Pixel = 30 91
# Skipping Pixel = 30 92
# Skipping Pixel = 31 9
# Skipping Pixel = 31 10
# Skipping Pixel = 31 90
# Skipping Pixel = 31 91
# Skipping Pixel = 31 92
# Skipping Pixel = 32 9
# Skipping Pixel = 32 10
# Skipping Pixel = 32 11
# Skipping Pixel = 32 12
# Skipping Pixel = 32 13
# Skipping Pixel = 32 15
# Skipping Pixel = 32 18
# Skipping Pixel = 32 78
# Skipping Pixel = 32 79
# Skipping Pixel = 32 90
# Skipping Pixel = 32 91
# Skipping Pixel = 32 92
# Skipping Pixel = 33 9
# Skipping Pixel = 33 10
# Skipping Pixel = 33 11
# Skipping Pixel = 33 12
# Skipping Pixel = 33 13
# Skipping Pixel = 33 78
# Skipping Pixel = 33 79
# Skipping Pixel = 33 90
# Skipping Pixel = 33 91
# Skipping Pixel = 33 92
# Skipping Pixel = 34 9
# Skipping Pixel = 34 12
# Skipping Pixel = 34 13
# Skipping Pixel = 34 91
# Skipping Pixel = 34 92
# Skipping Pixel = 35 90
# Skipping Pixel = 35 91
# Skipping Pixel = 35 92
# Skipping Pixel = 36 90
# Skipping Pixel = 36 91
# Skipping Pixel = 36 92
# Skipping Pixel = 37 92
# Skipping Pixel = 40 92
# Skipping Pixel = 41 89
# Skipping Pixel = 41 90
# Skipping Pixel = 41 91
# Skipping Pixel = 41 92
# Skipping Pixel = 42 89
# Skipping Pixel = 42 90
# Skipping Pixel = 42 91
# Skipping Pixel = 42 92
# Skipping Pixel = 43 81
# Skipping Pixel = 43 89
# Skipping Pixel = 43 90
# Skipping Pixel = 43 91
# Skipping Pixel = 43 92
# Skipping Pixel = 44 79
# Skipping Pixel = 44 80
# Skipping Pixel = 44 81
# Skipping Pixel = 44 82
# Skipping Pixel = 44 91
# Skipping Pixel = 44 92
# Skipping Pixel = 45 91
# Skipping Pixel = 45 92
# Skipping Pixel = 46 91
# Skipping Pixel = 46 92
# Skipping Pixel = 47 90
# Skipping Pixel = 52 84
# Skipping Pixel = 53 84
# Skipping Pixel = 53 85
# Skipping Pixel = 53 90
# Skipping Pixel = 53 91
# Skipping Pixel = 54 92
# Skipping Pixel = 58 12
# Skipping Pixel = 58 13
# Skipping Pixel = 58 14
# Skipping Pixel = 58 15
# Skipping Pixel = 59 9
# Skipping Pixel = 59 10
# Skipping Pixel = 59 11
# Skipping Pixel = 59 12
# Skipping Pixel = 59 13
# Skipping Pixel = 59 14
# Skipping Pixel = 60 9
# Skipping Pixel = 60 10
# Skipping Pixel = 60 13
# Skipping Pixel = 64 85
# Skipping Pixel = 69 9
# Skipping Pixel = 69 10
# Skipping Pixel = 69 11
# Skipping Pixel = 70 9
# Skipping Pixel = 70 10
# Skipping Pixel = 70 11
# Skipping Pixel = 71 9
# Skipping Pixel = 71 10
# Skipping Pixel = 72 9
# Skipping Pixel = 73 9
# Skipping Pixel = 74 9
# Skipping Pixel = 75 9
# Skipping Pixel = 76 9
# Skipping Pixel = 76 10
# Skipping Pixel = 77 9
# Skipping Pixel = 77 10
# Skipping Pixel = 78 9
# Skipping Pixel = 78 10
# Skipping Pixel = 79 9
# Skipping Pixel = 79 10
# Skipping Pixel = 80 9
# Skipping Pixel = 80 10
# Skipping Pixel = 81 9
# Skipping Pixel = 81 10
# Skipping Pixel = 82 9
# Skipping Pixel = 82 10
# Skipping Pixel = 82 11
# Skipping Pixel = 83 9
# Skipping Pixel = 83 10
# Skipping Pixel = 83 11
# Skipping Pixel = 83 86
# Skipping Pixel = 84 9
# Skipping Pixel = 84 10
# Skipping Pixel = 84 11
# Skipping Pixel = 84 86
# Skipping Pixel = 85 9
# Skipping Pixel = 85 10
# Skipping Pixel = 85 11
# Skipping Pixel = 86 9
# Skipping Pixel = 86 10
# Skipping Pixel = 86 11
# Skipping Pixel = 86 87
# Skipping Pixel = 87 9
# Skipping Pixel = 87 10
# Skipping Pixel = 87 11
# Skipping Pixel = 87 87
# Skipping Pixel = 87 88
# Skipping Pixel = 88 9
# Skipping Pixel = 88 10
# Skipping Pixel = 88 11
# Skipping Pixel = 88 87
# Skipping Pixel = 88 88
# Skipping Pixel = 88 89
# Skipping Pixel = 89 9
# Skipping Pixel = 89 10
# Skipping Pixel = 89 11
# Skipping Pixel = 89 12
# Skipping Pixel = 89 86
# Skipping Pixel = 89 87
# Skipping Pixel = 89 91
# Skipping Pixel = 90 9
# Skipping Pixel = 90 10
# Skipping Pixel = 90 11
# Skipping Pixel = 90 12
# Skipping Pixel = 90 86
# Skipping Pixel = 91 9
# Skipping Pixel = 91 10
# Skipping Pixel = 91 11
# Skipping Pixel = 91 12
# Skipping Pixel = 91 13
# Skipping Pixel = 91 85
# Skipping Pixel = 91 86
# Skipping Pixel = 91 91
# Skipping Pixel = 92 9
# Skipping Pixel = 92 10
# Skipping Pixel = 92 11
# Skipping Pixel = 92 12
# Skipping Pixel = 92 13
# Skipping Pixel = 92 85
# Skipping Pixel = 92 86
# Skipping Pixel = 92 87
# Skipping Pixel = 92 91
# Skipping Pixel = 92 92
# Skipping Pixel = 93 9
# Skipping Pixel = 93 10
# Skipping Pixel = 93 11
# Skipping Pixel = 93 12
# Skipping Pixel = 93 84
# Skipping Pixel = 93 85
# Skipping Pixel = 93 86
# Skipping Pixel = 93 87
# Skipping Pixel = 93 88
# Skipping Pixel = 93 89
# Skipping Pixel = 94 9
# Skipping Pixel = 94 10
# Skipping Pixel = 94 11
# Skipping Pixel = 94 12
# Skipping Pixel = 94 82
# Skipping Pixel = 94 83
# Skipping Pixel = 94 84
# Skipping Pixel = 94 85
# Skipping Pixel = 94 86
# Skipping Pixel = 94 87
# Skipping Pixel = 94 88
# Skipping Pixel = 94 89
# Skipping Pixel = 95 9
# Skipping Pixel = 95 10
# Skipping Pixel = 95 11
# Skipping Pixel = 95 12
# Skipping Pixel = 95 13
# Skipping Pixel = 95 73
# Skipping Pixel = 95 82
# Skipping Pixel = 95 83
# Skipping Pixel = 95 84
# Skipping Pixel = 95 85
# Skipping Pixel = 95 86
# Skipping Pixel = 95 87
# Skipping Pixel = 95 88
# Skipping Pixel = 95 89
# Skipping Pixel = 96 9
# Skipping Pixel = 96 10
# Skipping Pixel = 96 11
# Skipping Pixel = 96 12
# Skipping Pixel = 96 13
# Skipping Pixel = 96 14
# Skipping Pixel = 96 15
# Skipping Pixel = 96 82
# Skipping Pixel = 96 83
# Skipping Pixel = 96 84
# Skipping Pixel = 96 85
# Skipping Pixel = 96 86
# Skipping Pixel = 96 87
# Skipping Pixel = 96 88
# Skipping Pixel = 96 89
# Skipping Pixel = 96 90
# Skipping Pixel = 97 9
# Skipping Pixel = 97 10
# Skipping Pixel = 97 11
# Skipping Pixel = 97 12
# Skipping Pixel = 97 13
# Skipping Pixel = 97 14
# Skipping Pixel = 97 15
# Skipping Pixel = 97 70
# Skipping Pixel = 97 81
# Skipping Pixel = 97 82
# Skipping Pixel = 97 83
# Skipping Pixel = 97 84
# Skipping Pixel = 97 85
# Skipping Pixel = 97 86
# Skipping Pixel = 97 87
# Skipping Pixel = 97 88
# Skipping Pixel = 97 89
# Skipping Pixel = 97 90
# Skipping Pixel = 97 91
# Skipping Pixel = 97 92
# Skipping Pixel = 98 9
# Skipping Pixel = 98 10
# Skipping Pixel = 98 11
# Skipping Pixel = 98 12
# Skipping Pixel = 98 13
# Skipping Pixel = 98 14
# Skipping Pixel = 98 15
# Skipping Pixel = 98 69
# Skipping Pixel = 98 70
# Skipping Pixel = 98 75
# Skipping Pixel = 98 80
# Skipping Pixel = 98 81
# Skipping Pixel = 98 82
# Skipping Pixel = 98 83
# Skipping Pixel = 98 84
# Skipping Pixel = 98 85
# Skipping Pixel = 98 86
# Skipping Pixel = 98 87
# Skipping Pixel = 98 88
# Skipping Pixel = 98 89
# Skipping Pixel = 98 90
# Skipping Pixel = 98 91
# Skipping Pixel = 98 92
# Skipping Pixel = 99 9
# Skipping Pixel = 99 10
# Skipping Pixel = 99 11
# Skipping Pixel = 99 12
# Skipping Pixel = 99 13
# Skipping Pixel = 99 14
# Skipping Pixel = 99 15
# Skipping Pixel = 99 16
# Skipping Pixel = 99 69
# Skipping Pixel = 99 70
# Skipping Pixel = 99 71
# Skipping Pixel = 99 75
# Skipping Pixel = 99 76
# Skipping Pixel = 99 77
# Skipping Pixel = 99 78
# Skipping Pixel = 99 79
# Skipping Pixel = 99 80
# Skipping Pixel = 99 81
# Skipping Pixel = 99 82
# Skipping Pixel = 99 83
# Skipping Pixel = 99 84
# Skipping Pixel = 99 85
# Skipping Pixel = 99 86
# Skipping Pixel = 99 87
# Skipping Pixel = 99 88
# Skipping Pixel = 99 89
# Skipping Pixel = 99 90
# Skipping Pixel = 99 91
# Skipping Pixel = 99 92
# Skipping Pixel = 100 9
# Skipping Pixel = 100 10
# Skipping Pixel = 100 11
# Skipping Pixel = 100 12
# Skipping Pixel = 100 13
# Skipping Pixel = 100 14
# Skipping Pixel = 100 15
# Skipping Pixel = 100 16
# Skipping Pixel = 100 56
# Skipping Pixel = 100 69
# Skipping Pixel = 100 70
# Skipping Pixel = 100 71
# Skipping Pixel = 100 72
# Skipping Pixel = 100 73
# Skipping Pixel = 100 78
# Skipping Pixel = 100 79
# Skipping Pixel = 100 80
# Skipping Pixel = 100 81
# Skipping Pixel = 100 82
# Skipping Pixel = 100 83
# Skipping Pixel = 100 84
# Skipping Pixel = 100 85
# Skipping Pixel = 100 86
# Skipping Pixel = 100 87
# Skipping Pixel = 100 88
# Skipping Pixel = 100 89
# Skipping Pixel = 100 90
# Skipping Pixel = 100 91
# Skipping Pixel = 100 92
# Skipping Pixel = 101 9
# Skipping Pixel = 101 10
# Skipping Pixel = 101 11
# Skipping Pixel = 101 12
# Skipping Pixel = 101 13
# Skipping Pixel = 101 14
# Skipping Pixel = 101 15
# Skipping Pixel = 101 16
# Skipping Pixel = 101 56
# Skipping Pixel = 101 65
# Skipping Pixel = 101 66
# Skipping Pixel = 101 67
# Skipping Pixel = 101 68
# Skipping Pixel = 101 69
# Skipping Pixel = 101 70
# Skipping Pixel = 101 71
# Skipping Pixel = 101 72
# Skipping Pixel = 101 73
# Skipping Pixel = 101 78
# Skipping Pixel = 101 79
# Skipping Pixel = 101 80
# Skipping Pixel = 101 81
# Skipping Pixel = 101 82
# Skipping Pixel = 101 83
# Skipping Pixel = 101 84
# Skipping Pixel = 101 85
# Skipping Pixel = 101 86
# Skipping Pixel = 101 87
# Skipping Pixel = 101 88
# Skipping Pixel = 101 89
# Skipping Pixel = 101 90
# Skipping Pixel = 101 91
# Skipping Pixel = 101 92
# Skipping Pixel = 102 9
# Skipping Pixel = 102 10
# Skipping Pixel = 102 11
# Skipping Pixel = 102 12
# Skipping Pixel = 102 13
# Skipping Pixel = 102 14
# Skipping Pixel = 102 15
# Skipping Pixel = 102 16
# Skipping Pixel = 102 57
# Skipping Pixel = 102 60
# Skipping Pixel = 102 65
# Skipping Pixel = 102 66
# Skipping Pixel = 102 67
# Skipping Pixel = 102 68
# Skipping Pixel = 102 69
# Skipping Pixel = 102 70
# Skipping Pixel = 102 71
# Skipping Pixel = 102 72
# Skipping Pixel = 102 73
# Skipping Pixel = 102 78
# Skipping Pixel = 102 79
# Skipping Pixel = 102 80
# Skipping Pixel = 102 81
# Skipping Pixel = 102 82
# Skipping Pixel = 102 83
# Skipping Pixel = 102 84
# Skipping Pixel = 102 85
# Skipping Pixel = 102 86
# Skipping Pixel = 102 87
# Skipping Pixel = 102 88
# Skipping Pixel = 102 89
# Skipping Pixel = 102 90
# Skipping Pixel = 102 91
# Skipping Pixel = 102 92
# Skipping Pixel = 103 9
# Skipping Pixel = 103 10
# Skipping Pixel = 103 11
# Skipping Pixel = 103 12
# Skipping Pixel = 103 13
# Skipping Pixel = 103 14
# Skipping Pixel = 103 15
# Skipping Pixel = 103 16
# Skipping Pixel = 103 57
# Skipping Pixel = 103 58
# Skipping Pixel = 103 59
# Skipping Pixel = 103 60
# Skipping Pixel = 103 66
# Skipping Pixel = 103 67
# Skipping Pixel = 103 68
# Skipping Pixel = 103 69
# Skipping Pixel = 103 70
# Skipping Pixel = 103 71
# Skipping Pixel = 103 72
# Skipping Pixel = 103 73
# Skipping Pixel = 103 74
# Skipping Pixel = 103 77
# Skipping Pixel = 103 78
# Skipping Pixel = 103 79
# Skipping Pixel = 103 80
# Skipping Pixel = 103 81
# Skipping Pixel = 103 82
# Skipping Pixel = 103 83
# Skipping Pixel = 103 84
# Skipping Pixel = 103 85
# Skipping Pixel = 103 86
# Skipping Pixel = 103 87
# Skipping Pixel = 103 88
# Skipping Pixel = 103 89
# Skipping Pixel = 103 90
# Skipping Pixel = 103 91
# Skipping Pixel = 103 92
# Skipping Pixel = 104 9
# Skipping Pixel = 104 10
# Skipping Pixel = 104 11
# Skipping Pixel = 104 12
# Skipping Pixel = 104 13
# Skipping Pixel = 104 14
# Skipping Pixel = 104 15
# Skipping Pixel = 104 57
# Skipping Pixel = 104 58
# Skipping Pixel = 104 59
# Skipping Pixel = 104 60
# Skipping Pixel = 104 61
# Skipping Pixel = 104 66
# Skipping Pixel = 104 67
# Skipping Pixel = 104 68
# Skipping Pixel = 104 69
# Skipping Pixel = 104 70
# Skipping Pixel = 104 71
# Skipping Pixel = 104 72
# Skipping Pixel = 104 73
# Skipping Pixel = 104 74
# Skipping Pixel = 104 75
# Skipping Pixel = 104 76
# Skipping Pixel = 104 77
# Skipping Pixel = 104 78
# Skipping Pixel = 104 79
# Skipping Pixel = 104 80
# Skipping Pixel = 104 81
# Skipping Pixel = 104 82
# Skipping Pixel = 104 83
# Skipping Pixel = 104 84
# Skipping Pixel = 104 85
# Skipping Pixel = 104 86
# Skipping Pixel = 104 87
# Skipping Pixel = 104 88
# Skipping Pixel = 104 89
# Skipping Pixel = 104 90
# Skipping Pixel = 104 91
# Skipping Pixel = 104 92

# %% [markdown]
# For sanity check, let us visualize one dispersion function. We choose a pixel towards the center of the image

# %%
epix = (50,50) # Example pixel
lvec = res1[0][epix]/3600. # \ell^2 values
disp_f = res1[1][epix] # Dispersion function
disp_f_err = res1[2][epix] # Dispersion errors
plt.errorbar(lvec,disp_f,yerr=disp_f_err,fmt='bo')
plt.xlabel(r'$\ell^{2}$ [arcmin$^{2}$]')
plt.ylabel(r'$1-\langle \cos(\Delta\phi)\rangle$')
# Out:
# Text(0, 0.5, '$1-\\langle \\cos(\\Delta\\phi)\\rangle$')

# %% [markdown]
# This *dispersion function* looks reasonable since we can see a fairly linear regime for $\sim$0.125-1 arcmin$^{2}$.
# Step 3: fitting the *dispersion functions*. This is step is similar to that of Tutorial III, in which we fitted one function using the MCMC fitter. Here, such approach is applied to every pixel with a valid *dispersion function*. From such fits we determine the maps of paremeters. To accelerate this process, we only fit a subregion of the entire 214 $\mu$m data,

# %%
m_lvec = res1[0][40:60,40:60,:] # in arcsec^2 (20 x 20 pixels region around the example pixel)
m_disp_f = res1[1][40:60,40:60,:] # dispersion function (sub)map
m_disp_f_err = res1[2][40:60,40:60,:] # dispersion errors (sub)map

# %% [markdown]
# The function *mcmc_fit_map* uses several more keywords than *mcmc_fit* since it is implemented in a way that can be parallelized. That is, fitting processes corresponding to different pixels can be sent to different cores (this process does not require communication between the different processes). Besdides the necessary inputs (dispersion function map, their uncertainties, $\ell$ values, kernel size (in pixels), beam size (in arcsecs), we can provide initial-guess values for the parameters $a_{2}$, $\delta$, and $\Delta^{\prime}/[\langle B_{t}^{2}\rangle/\langle B_{0}^{2}\rangle]$. Keyword *num* sets the number of random walkers and iterations for the MCMC fittting and its default value is 500. Keyword *n_cores* allows you to select the number of cores/processes to be executed and its default value (*n_cores=False*) is half of available cores.

# %%
res2 = fitting.mcmc_fit_map(m_disp_f,m_lvec,m_disp_f_err,win_s,pixel_size,beam=beam_s,a2=1.0E-3,delta=30.,f=100.,
                            num=200,verb=False,n_cores=False)
# Out:
# Running MCMC fitting in 6 cores

# %% [markdown]
# The output of *mcmc_fit_map* is a dictionary with maps of all three parameters mentioned above, plus maps of goodness-of-fit $\chi$ and non-linear rank correlation coefficient $\rho$.
#
# Let us inspect the fit for the example pixel plotted above,

# %%
l = np.arange(0,10000) # define some values of \ell^2 in arcsec for the model
# Choose the same pixel example
# Evaluate the two-scale function
nepix = (10,10) # since it will correspond to epix in our sub-array
a2 = res2['a'][nepix]# arcsec^-2
delta = res2['d'][nepix] # arcsec
ratio = res2['f'][nepix] # arcsec
f = fitting.model_funct(l,a2,delta,ratio,beam=beam_s)

# %% [markdown]
# Replot the dispersion function and fit,

# %%
lvec = res1[0][epix]/3600.
disp_f = res1[1][epix]
disp_f_err = res1[2][epix]
plt.figure(figsize=(7,6))
plt.errorbar(lvec,disp_f,yerr=res2['chi'][10,10]*disp_f_err,fmt='bo')
plt.xlabel(r'$\ell^{2}$ [arcmin$^{2}$]')
plt.ylabel(r'$1-\langle \cos(\Delta\phi)\rangle$')
lratio = r'$\Delta^{\prime}/[\langle B_{t}^{2}\rangle/\langle B_{0}^{2}\rangle]$'
label = r'Two-scale model with: $a_{2}$=%2.2f, $\delta$=%2.2f, %s=%2.2f'%(a2*3600.,delta,lratio,ratio)
plt.plot(l/3600., f,c='red',label=label)
plt.ylim([0.,0.05])
plt.xlim([0.,1.5])
plt.legend()

# %% [markdown]
# We can see from this plot that the MCMC solver finds parameter values that describe the data well. Better parameters can be obtained by giving *mcmc_fit_map* different initial-guess values or a larger number of walker/iterations. Good initial-guess values are those obtained by the dispersion analysis performed to the entire region, such as described in Tutorial III.
#
# For consistency to values reported in Guerra+21, we print the parameters fro this fit

# %%
a2 = res2['a'][nepix]*3600.*1000 # Units of 10^{-3} arcmin^{-2}
print("a_2 = %2.3E [arcmin^-2]"%a2)
# Out:
# a_2 = 2.639E+01 [arcmin^-2]

# %%
print("delta = %2.2f [arcsec]"%delta)
# Out:
# delta = 16.72 [arcsec]

# %%
Delta_p *= 60. # Cloud's depth in arcsec
ratio = Delta_p/res2['f'][nepix]
print("ratio = %2.2f"%ratio)
# Out:
# ratio = 0.07

# %% [markdown]
# We can now visualize the maps of parameters calculated,

# %%
a2_map = res2['a']*3600*1000 # Units of 10^{-3} arcmin^{-2}
delta_map = res2['d'] # arcsec
ratio_map = Delta_p/res2['f']
plt.figure(figsize=(20,5))
fig,(ax1,ax2,ax3) = plt.subplots(ncols=3,nrows=1)
g = ax1.imshow(a2_map,origin='lower',vmin=1.,vmax=100.)
plt.colorbar(g,ax=ax1,orientation='horizontal',label=r'[10$^{-3}$ arcmin$^{-2}$]')
ax1.set_title(r'$a_{2}$')
g = ax2.imshow(delta_map,origin='lower',vmin=0.,vmax=50.)
plt.colorbar(g,ax=ax2,orientation='horizontal', label='[arcsec]')
ax2.set_title(r'$\delta$')
g = ax3.imshow(ratio_map,origin='lower',vmin=0.,vmax=1.)
plt.colorbar(g,ax=ax3,orientation='horizontal',label='')
bratio = r'$\langle B_{t}^{2}\rangle/\langle B_{0}^{2}\rangle$'
ax3.set_title(bratio)
# Out:
# Text(0.5, 1.0, '$\\langle B_{t}^{2}\\rangle/\\langle B_{0}^{2}\\rangle$')

# %% [markdown]
# The MCMC solver sometimes provides solutions for pixels that are out-of-statistics for their inmediate region. See for example the value ~100 in the $\a_{2}$ around the pixel (10,15). Therefore, we can "clean" the maps by performing a $\sigma$ clipping. That is, each pixel value is compared to the statistics in a 3x3 pixels kernel aroudn it. If the value is outside the range $median \pm n\sigma$ then the value for the such pixel is interpolated from its nearest neighbors.
#
# In this case we choose $n=2$,

# %%
c_a2_map = utils.clean_map(a2_map,sigma=2,w=3)
c_delta_map = utils.clean_map(delta_map,sigma=2,w=3)
c_ratio_map = utils.clean_map(ratio_map,sigma=2,w=3)

# %% [markdown]
# And visualize the "clean" maps,

# %%
plt.figure(figsize=(20,5))
fig,(ax1,ax2,ax3) = plt.subplots(ncols=3,nrows=1)
g = ax1.imshow(c_a2_map,origin='lower',vmin=1.,vmax=100.)
plt.colorbar(g,ax=ax1,orientation='horizontal',label=r'[10$^{-3}$ arcmin$^{-2}$]')
ax1.set_title(r'$a_{2}$')
g = ax2.imshow(c_delta_map,origin='lower',vmin=0.,vmax=50.)
plt.colorbar(g,ax=ax2,orientation='horizontal', label='[arcsec]')
ax2.set_title(r'$\delta$')
g = ax3.imshow(c_ratio_map,origin='lower',vmin=0.,vmax=1.)
plt.colorbar(g,ax=ax3,orientation='horizontal',label='')
bratio = r'$\langle B_{t}^{2}\rangle/\langle B_{0}^{2}\rangle$'
ax3.set_title(bratio)
fig.suptitle('Clean Maps')
# Out:
# Text(0.5, 0.98, 'Clean Maps')

# %% [markdown]
# We see in these clean maps that the large value in the middle of the $a_{2}$ map dissapeared. The overall spatial distribution of the maps appears "smoother". However, changing the value of $\sigma$ or $w$ can help make these maps even smoother.
#
# We now save these maps into a pickle file for using in Tutorial V where we will use the $bratio$ map for computing a map of $B_{\rm POS}$ using the DCF approximations,

# %%
res3 = {'a2_map':c_a2_map,'delta_map':c_delta_map,'ratio_map':c_ratio_map}
import pickle
pickle.dump(res3,open(cdir+'/data/disp_analysis_maps.pk',"wb"))
